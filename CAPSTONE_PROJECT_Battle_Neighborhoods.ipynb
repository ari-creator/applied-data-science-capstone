# %% [markdown]
# **Capstone Project - The Battle of Neighborhoods (Week 1-2)**
# Business Problem section
# Background
# According to Bloomberg News, the London Housing Market is in a rut. It is now facing a number of different headwinds, including the prospect of higher taxes and a warning from the Bank of England that U.K. home values could fall as much as 30 percent in the event of a disorderly exit from the European Union. More specifically, four overlooked cracks suggest that the London market may be in worse shape than many realize: hidden price falls, record-low sales, homebuilder exodus and tax hikes addressing overseas buyers of homes in England and Wales.
#
# **Business Problem**
# In this scenario, it is urgent to adopt machine learning tools in order to assist homebuyers clientele in London to make wise and effective decisions. As a result, the business problem we are currently posing is: how could we provide support to homebuyers clientele in to purchase a suitable real estate in London in this uncertain economic and financial scenario?
#
# To solve this business problem, we are going to cluster London neighborhoods in order to recommend venues and the current average price of real estate where homebuyers can make a real estate investment. We will recommend profitable venues according to amenities and essential facilities surrounding such venues i.e. elementary schools, high schools, hospitals & grocery stores.
#
# **Data section**
# Data on London properties and the relative price paid data were extracted from the HM Land Registry (http://landregistry.data.gov.uk/). The following fields comprise the address data included in Price Paid Data: Postcode; PAON Primary Addressable Object Name. Typically the house number or name; SAON Secondary Addressable Object Name. If there is a sub-building, for example, the building is divided into flats, there will be a SAON; Street; Locality; Town/City; District; County.
#
# To explore and target recommended locations across different venues according to the presence of amenities and essential facilities, we will access data through FourSquare API interface and arrange them as a dataframe for visualization. By merging data on London properties and the relative price paid data from the HM Land Registry and data on amenities and essential facilities surrounding such properties from FourSquare API interface, we will be able to recommend profitable real estate investments.
#
#  **Methodology section**
# The Methodology section will describe the main components of our analysis and predication system. The Methodology section comprises four stages:
#
# 1. Collect Inspection Data
# 2. Explore and Understand Data
# 3. Data preparation and preprocessing
# 4. Modeling

# %% [markdown]
# 1. **Collect Inspection Data**

# %% [markdown]
# After importing the necessary libraries, we download the data from the HM Land Registry website as follows:

# %%
import os # Operating System
import numpy as np
import pandas as pd
import datetime as dt # Datetime
import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes
import folium #import folium # map rendering library

print('Libraries imported.')
# Out:
# /bin/bash: conda: command not found
# /bin/bash: conda: command not found
# Libraries imported.

# %%
#Read the data for examination (Source: http://landregistry.data.gov.uk/)
df_ppd = pd.read_csv("http://prod2.publicdata.landregistry.gov.uk.s3-website-eu-west-1.amazonaws.com/pp-2018.csv")

# %% [markdown]
# Before using data, we will have to explore and understand it.
#
# 2. Explore and Understand Data
# We read the dataset that we collected from the HM Land Registry website into a pandas' data frame and display the first five rows of it as follows:

# %%
df_ppd.head(5)
# Out:
#    {726BF13A-993E-0A46-E053-6C04A8C01D0D}   75000  ...  A A.1
# 0  {726BF13A-993F-0A46-E053-6C04A8C01D0D}  115000  ...  A   A
# 1  {726BF13A-9940-0A46-E053-6C04A8C01D0D}   24000  ...  A   A
# 2  {726BF13A-9941-0A46-E053-6C04A8C01D0D}   56000  ...  A   A
# 3  {726BF13A-9942-0A46-E053-6C04A8C01D0D}  220000  ...  A   A
# 4  {726BF13A-9943-0A46-E053-6C04A8C01D0D}   58000  ...  A   A
#
# [5 rows x 16 columns]

# %%
df_ppd.shape
# Out:
# (1032408, 16)

# %% [markdown]
# Our dataset consists of over 1030000 rows and 16 columns. We will now prepare and preprocess data accordingly.

# %% [markdown]
# 3. **Data preparation and preprocessing**
# At this stage, we prepare our dataset for the modeling process, opting for the most suitable machine learning algorithm for our scope. Accordingly, we perform the following steps:
#
# Rename the column names
# Format the date column
# Sort data by date of sale
# Select data only for the city of London
# Make a list of street names in London
# Calculate the street-wise average price of the property
# Read the street-wise coordinates into a data frame, eliminating recurring word London from individual names
# Join the data to find the coordinates of locations which fit into client's budget
# Plot recommended locations on London map along with current market prices

# %%
# Assign meaningful column names
df_ppd.columns = ['TUID', 'Price', 'Date_Transfer', 'Postcode', 'Prop_Type', 'Old_New', 'Duration', 'PAON', \
                  'SAON', 'Street', 'Locality', 'Town_City', 'District', 'County', 'PPD_Cat_Type', 'Record_Status']

# %%
# Format the date column
df_ppd['Date_Transfer'] = df_ppd['Date_Transfer'].apply(pd.to_datetime)

# Delete all obsolete transactions which were done before 2016
df_ppd.drop(df_ppd[df_ppd.Date_Transfer.dt.year < 2016].index, inplace=True)

# Sort by Date of Sale
df_ppd.sort_values(by=['Date_Transfer'],ascending=[False],inplace=True)

# %%
df_ppd_london = df_ppd.query("Town_City == 'LONDON'")

# Make a list of street names in LONDON
streets = df_ppd_london['Street'].unique().tolist()

# %%
df_grp_price = df_ppd_london.groupby(['Street'])['Price'].mean().reset_index()

# Give meaningful names to the columns
df_grp_price.columns = ['Street', 'Avg_Price']

# %%
#Input your Budget's Upper Limit and Lower Limit - Find the locations df_grp_price which fits your budget
df_affordable = df_grp_price.query("(Avg_Price >= 2200000) & (Avg_Price <= 2500000)")

# %%
# Display the dataframe
df_affordable
# Out:
#                    Street  Avg_Price
# 196         ALBION SQUARE  2450000.0
# 390           ANHALT ROAD  2435000.0
# 405       ANSDELL TERRACE  2250000.0
# 422       APPLEGARTH ROAD  2400000.0
# 857       BARONSMEAD ROAD  2375000.0
# ...                   ...        ...
# 13736      WILFRED STREET  2410538.5
# 13762  WILLOW BRIDGE ROAD  2425000.0
# 13782       WILSON STREET  2257500.0
# 13811     WINCHENDON ROAD  2350000.0
# 13848        WINGATE ROAD  2206400.0
#
# [159 rows x 2 columns]

# %%
import pandas as pd
import numpy as np
import datetime as DT
import hmac
from geopy.geocoders import Nominatim
from geopy.distance import vincenty
# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
for index, item in df_affordable.iterrows():
    print(f"index: {index}")
    print(f"item: {item}")
    print(f"item.Street only: {item.Street}")
# Out:
# index: 196
# item: Street       ALBION SQUARE
# Avg_Price         2.45e+06
# Name: 196, dtype: object
# item.Street only: ALBION SQUARE
# index: 390
# item: Street       ANHALT ROAD
# Avg_Price      2.435e+06
# Name: 390, dtype: object
# item.Street only: ANHALT ROAD
# index: 405
# item: Street       ANSDELL TERRACE
# Avg_Price           2.25e+06
# Name: 405, dtype: object
# item.Street only: ANSDELL TERRACE
# index: 422
# item: Street       APPLEGARTH ROAD
# Avg_Price            2.4e+06
# Name: 422, dtype: object
# item.Street only: APPLEGARTH ROAD
# index: 857
# item: Street       BARONSMEAD ROAD
# Avg_Price          2.375e+06
# Name: 857, dtype: object
# item.Street only: BARONSMEAD ROAD
# index: 983
# item: Street       BEAUCLERC ROAD
# Avg_Price          2.48e+06
# Name: 983, dtype: object
# item.Street only: BEAUCLERC ROAD
# index: 1105
# item: Street       BELVEDERE DRIVE
# Avg_Price           2.34e+06
# Name: 1105, dtype: object
# item.Street only: BELVEDERE DRIVE
# index: 1218
# item: Street       BICKENHALL STREET
# Avg_Price           2.2085e+06
# Name: 1218, dtype: object
# item.Street only: BICKENHALL STREET
# index: 1256
# item: Street       BIRCHLANDS AVENUE
# Avg_Price            2.217e+06
# Name: 1256, dtype: object
# item.Street only: BIRCHLANDS AVENUE
# index: 1556
# item: Street       BRAMPTON GROVE
# Avg_Price       2.45688e+06
# Name: 1556, dtype: object
# item.Street only: BRAMPTON GROVE
# index: 1635
# item: Street       BRIARDALE GARDENS
# Avg_Price          2.39713e+06
# Name: 1635, dtype: object
# item.Street only: BRIARDALE GARDENS
# index: 1800
# item: Street       BROOKWAY
# Avg_Price     2.4e+06
# Name: 1800, dtype: object
# item.Street only: BROOKWAY
# index: 1983
# item: Street        BURY WALK
# Avg_Price    2.4925e+06
# Name: 1983, dtype: object
# item.Street only: BURY WALK
# index: 2071
# item: Street       CALLCOTT STREET
# Avg_Price          2.375e+06
# Name: 2071, dtype: object
# item.Street only: CALLCOTT STREET
# index: 2132
# item: Street       CAMPDEN HILL ROAD
# Avg_Price          2.37965e+06
# Name: 2132, dtype: object
# item.Street only: CAMPDEN HILL ROAD
# index: 2139
# item: Street       CAMPION ROAD
# Avg_Price       2.461e+06
# Name: 2139, dtype: object
# item.Street only: CAMPION ROAD
# index: 2161
# item: Street       CANNING PLACE
# Avg_Price        2.425e+06
# Name: 2161, dtype: object
# item.Street only: CANNING PLACE
# index: 2228
# item: Street       CARLISLE ROAD
# Avg_Price          2.2e+06
# Name: 2228, dtype: object
# item.Street only: CARLISLE ROAD
# index: 2233
# item: Street       CARLTON GARDENS
# Avg_Price         2.4835e+06
# Name: 2233, dtype: object
# item.Street only: CARLTON GARDENS
# index: 2245
# item: Street       CARLYLE COURT
# Avg_Price          2.3e+06
# Name: 2245, dtype: object
# item.Street only: CARLYLE COURT
# index: 2408
# item: Street       CHALCOT SQUARE
# Avg_Price       2.28668e+06
# Name: 2408, dtype: object
# item.Street only: CHALCOT SQUARE
# index: 2486
# item: Street       CHARLES LANE
# Avg_Price       2.414e+06
# Name: 2486, dtype: object
# item.Street only: CHARLES LANE
# index: 2564
# item: Street       CHELSEA CRESCENT
# Avg_Price           2.495e+06
# Name: 2564, dtype: object
# item.Street only: CHELSEA CRESCENT
# index: 2608
# item: Street       CHESTER CLOSE NORTH
# Avg_Price               2.45e+06
# Name: 2608, dtype: object
# item.Street only: CHESTER CLOSE NORTH
# index: 2640
# item: Street       CHEYNE COURT
# Avg_Price        2.25e+06
# Name: 2640, dtype: object
# item.Street only: CHEYNE COURT
# index: 2643
# item: Street       CHEYNE ROW
# Avg_Price      2.41e+06
# Name: 2643, dtype: object
# item.Street only: CHEYNE ROW
# index: 2688
# item: Street       CHISWICK MALL
# Avg_Price       2.2875e+06
# Name: 2688, dtype: object
# item.Street only: CHISWICK MALL
# index: 2763
# item: Street         CITY ROAD
# Avg_Price    2.46834e+06
# Name: 2763, dtype: object
# item.Street only: CITY ROAD
# index: 2810
# item: Street       CLARENDON STREET
# Avg_Price            2.25e+06
# Name: 2810, dtype: object
# item.Street only: CLARENDON STREET
# index: 2902
# item: Street       CLONCURRY STREET
# Avg_Price         2.38833e+06
# Name: 2902, dtype: object
# item.Street only: CLONCURRY STREET
# index: 2946
# item: Street       COLBECK MEWS
# Avg_Price      2.3675e+06
# Name: 2946, dtype: object
# item.Street only: COLBECK MEWS
# index: 2997
# item: Street       COLLEGE CRESCENT
# Avg_Price            2.44e+06
# Name: 2997, dtype: object
# item.Street only: COLLEGE CRESCENT
# index: 3204
# item: Street       CORNWALL TERRACE MEWS
# Avg_Price                 2.35e+06
# Name: 3204, dtype: object
# item.Street only: CORNWALL TERRACE MEWS
# index: 3257
# item: Street       COURT LANE GARDENS
# Avg_Price              2.36e+06
# Name: 3257, dtype: object
# item.Street only: COURT LANE GARDENS
# index: 3379
# item: Street       CRESCENT GROVE
# Avg_Price         2.298e+06
# Name: 3379, dtype: object
# item.Street only: CRESCENT GROVE
# index: 3585
# item: Street       DALEBURY ROAD
# Avg_Price          2.4e+06
# Name: 3585, dtype: object
# item.Street only: DALEBURY ROAD
# index: 3850
# item: Street       DEWHURST ROAD
# Avg_Price        2.425e+06
# Name: 3850, dtype: object
# item.Street only: DEWHURST ROAD
# index: 3931
# item: Street       DORIA ROAD
# Avg_Price    2.3625e+06
# Name: 3931, dtype: object
# item.Street only: DORIA ROAD
# index: 3982
# item: Street       DOWNSHIRE HILL
# Avg_Price         2.225e+06
# Name: 3982, dtype: object
# item.Street only: DOWNSHIRE HILL
# index: 4037
# item: Street       DUCHESS WALK
# Avg_Price      2.4775e+06
# Name: 4037, dtype: object
# item.Street only: DUCHESS WALK
# index: 4234
# item: Street       ECCLESTON SQUARE MEWS
# Avg_Price               2.3355e+06
# Name: 4234, dtype: object
# item.Street only: ECCLESTON SQUARE MEWS
# index: 4287
# item: Street       EGBERT STREET
# Avg_Price        2.265e+06
# Name: 4287, dtype: object
# item.Street only: EGBERT STREET
# index: 4291
# item: Street       EGERTON PLACE
# Avg_Price          2.2e+06
# Name: 4291, dtype: object
# item.Street only: EGERTON PLACE
# index: 4377
# item: Street       ELM PARK ROAD
# Avg_Price      2.32042e+06
# Name: 4377, dtype: object
# item.Street only: ELM PARK ROAD
# index: 4896
# item: Street       FLORAL STREET
# Avg_Price      2.22722e+06
# Name: 4896, dtype: object
# item.Street only: FLORAL STREET
# index: 5019
# item: Street       FRANK DIXON WAY
# Avg_Price         2.2125e+06
# Name: 5019, dtype: object
# item.Street only: FRANK DIXON WAY
# index: 5101
# item: Street       FULTON MEWS
# Avg_Price      2.299e+06
# Name: 5101, dtype: object
# item.Street only: FULTON MEWS
# index: 5244
# item: Street       GERARD ROAD
# Avg_Price     2.2585e+06
# Name: 5244, dtype: object
# item.Street only: GERARD ROAD
# index: 5247
# item: Street       GERRARD ROAD
# Avg_Price      2.2425e+06
# Name: 5247, dtype: object
# item.Street only: GERRARD ROAD
# index: 5292
# item: Street       GIRDLERS ROAD
# Avg_Price      2.44167e+06
# Name: 5292, dtype: object
# item.Street only: GIRDLERS ROAD
# index: 5385
# item: Street       GLOUCESTER CRESCENT
# Avg_Price            2.35083e+06
# Name: 5385, dtype: object
# item.Street only: GLOUCESTER CRESCENT
# index: 5454
# item: Street       GORDON PLACE
# Avg_Price       2.477e+06
# Name: 5454, dtype: object
# item.Street only: GORDON PLACE
# index: 5490
# item: Street       GRAFTON SQUARE
# Avg_Price          2.27e+06
# Name: 5490, dtype: object
# item.Street only: GRAFTON SQUARE
# index: 5497
# item: Street       GRAHAM TERRACE
# Avg_Price         2.325e+06
# Name: 5497, dtype: object
# item.Street only: GRAHAM TERRACE
# index: 5957
# item: Street       HARMAN DRIVE
# Avg_Price      2.2625e+06
# Name: 5957, dtype: object
# item.Street only: HARMAN DRIVE
# index: 5981
# item: Street       HARRIS STREET
# Avg_Price      2.47177e+06
# Name: 5981, dtype: object
# item.Street only: HARRIS STREET
# index: 6045
# item: Street       HAVANNAH STREET
# Avg_Price        2.21731e+06
# Name: 6045, dtype: object
# item.Street only: HAVANNAH STREET
# index: 6117
# item: Street       HAZLEWELL ROAD
# Avg_Price           2.5e+06
# Name: 6117, dtype: object
# item.Street only: HAZLEWELL ROAD
# index: 6233
# item: Street       HEREFORD MEWS
# Avg_Price         2.31e+06
# Name: 6233, dtype: object
# item.Street only: HEREFORD MEWS
# index: 6253
# item: Street       HERONDALE AVENUE
# Avg_Price           2.475e+06
# Name: 6253, dtype: object
# item.Street only: HERONDALE AVENUE
# index: 6365
# item: Street       HIGHWOOD HILL
# Avg_Price       2.2525e+06
# Name: 6365, dtype: object
# item.Street only: HIGHWOOD HILL
# index: 6401
# item: Street       HILLGATE PLACE
# Avg_Price           2.2e+06
# Name: 6401, dtype: object
# item.Street only: HILLGATE PLACE
# index: 6512
# item: Street       HOLLYCROFT AVENUE
# Avg_Price          2.36138e+06
# Name: 6512, dtype: object
# item.Street only: HOLLYCROFT AVENUE
# index: 6516
# item: Street       HOLLYWOOD MEWS
# Avg_Price          2.35e+06
# Name: 6516, dtype: object
# item.Street only: HOLLYWOOD MEWS
# index: 6561
# item: Street       HONEYWELL ROAD
# Avg_Price       2.27833e+06
# Name: 6561, dtype: object
# item.Street only: HONEYWELL ROAD
# index: 6617
# item: Street       HORTENSIA ROAD
# Avg_Price       2.27592e+06
# Name: 6617, dtype: object
# item.Street only: HORTENSIA ROAD
# index: 6646
# item: Street       HOXTON SQUARE
# Avg_Price      2.23429e+06
# Name: 6646, dtype: object
# item.Street only: HOXTON SQUARE
# index: 6672
# item: Street       HUNTER ROAD
# Avg_Price        2.3e+06
# Name: 6672, dtype: object
# item.Street only: HUNTER ROAD
# index: 6831
# item: Street       JACKSONS LANE
# Avg_Price       2.3625e+06
# Name: 6831, dtype: object
# item.Street only: JACKSONS LANE
# index: 6891
# item: Street       JOHN STREET
# Avg_Price      2.235e+06
# Name: 6891, dtype: object
# item.Street only: JOHN STREET
# index: 7196
# item: Street       KINNERTON STREET
# Avg_Price          2.4856e+06
# Name: 7196, dtype: object
# item.Street only: KINNERTON STREET
# index: 7230
# item: Street       KNARESBOROUGH PLACE
# Avg_Price              2.325e+06
# Name: 7230, dtype: object
# item.Street only: KNARESBOROUGH PLACE
# index: 7250
# item: Street       KNOX STREET
# Avg_Price       2.25e+06
# Name: 7250, dtype: object
# item.Street only: KNOX STREET
# index: 7339
# item: Street       LANCASTER MEWS
# Avg_Price        2.3125e+06
# Name: 7339, dtype: object
# item.Street only: LANCASTER MEWS
# index: 7410
# item: Street       LANSDOWNE ROAD
# Avg_Price       2.36488e+06
# Name: 7410, dtype: object
# item.Street only: LANSDOWNE ROAD
# index: 7439
# item: Street       LATIMER INDUSTRIAL ESTATE
# Avg_Price                      2.4e+06
# Name: 7439, dtype: object
# item.Street only: LATIMER INDUSTRIAL ESTATE
# index: 7492
# item: Street       LAXTON PLACE
# Avg_Price         2.5e+06
# Name: 7492, dtype: object
# item.Street only: LAXTON PLACE
# index: 7694
# item: Street       LINCOLN AVENUE
# Avg_Price        2.2035e+06
# Name: 7694, dtype: object
# item.Street only: LINCOLN AVENUE
# index: 7723
# item: Street       LINGFIELD ROAD
# Avg_Price       2.24875e+06
# Name: 7723, dtype: object
# item.Street only: LINGFIELD ROAD
# index: 7752
# item: Street       LISSON STREET
# Avg_Price       2.4625e+06
# Name: 7752, dtype: object
# item.Street only: LISSON STREET
# index: 7786
# item: Street       LIVERPOOL GROVE
# Avg_Price          2.288e+06
# Name: 7786, dtype: object
# item.Street only: LIVERPOOL GROVE
# index: 7878
# item: Street       LONGWOOD DRIVE
# Avg_Price         2.375e+06
# Name: 7878, dtype: object
# item.Street only: LONGWOOD DRIVE
# index: 7884
# item: Street       LONSDALE SQUARE
# Avg_Price         2.3575e+06
# Name: 7884, dtype: object
# item.Street only: LONSDALE SQUARE
# index: 8196
# item: Street       MANSFIELD STREET
# Avg_Price             2.5e+06
# Name: 8196, dtype: object
# item.Street only: MANSFIELD STREET
# index: 8422
# item: Street       MAZE HILL
# Avg_Price     2.25e+06
# Name: 8422, dtype: object
# item.Street only: MAZE HILL
# index: 8557
# item: Street       MIDDLESEX PASSAGE
# Avg_Price             2.28e+06
# Name: 8557, dtype: object
# item.Street only: MIDDLESEX PASSAGE
# index: 8722
# item: Street       MONTPELIER AVENUE
# Avg_Price              2.5e+06
# Name: 8722, dtype: object
# item.Street only: MONTPELIER AVENUE
# index: 8732
# item: Street       MONTPELIER WALK
# Avg_Price           2.32e+06
# Name: 8732, dtype: object
# item.Street only: MONTPELIER WALK
# index: 8881
# item: Street       MULTON ROAD
# Avg_Price        2.3e+06
# Name: 8881, dtype: object
# item.Street only: MULTON ROAD
# index: 8886
# item: Street       MUNDEN STREET
# Avg_Price         2.25e+06
# Name: 8886, dtype: object
# item.Street only: MUNDEN STREET
# index: 9160
# item: Street       NORFOLK CRESCENT
# Avg_Price         2.22333e+06
# Name: 9160, dtype: object
# item.Street only: NORFOLK CRESCENT
# index: 9183
# item: Street       NORTH CIRCULAR ROAD
# Avg_Price            2.39314e+06
# Name: 9183, dtype: object
# item.Street only: NORTH CIRCULAR ROAD
# index: 9259
# item: Street       NOTTINGHAM STREET
# Avg_Price           2.2275e+06
# Name: 9259, dtype: object
# item.Street only: NOTTINGHAM STREET
# index: 9334
# item: Street       OAKLEY STREET
# Avg_Price      2.38129e+06
# Name: 9334, dtype: object
# item.Street only: OAKLEY STREET
# index: 9345
# item: Street       OAKWOOD COURT
# Avg_Price      2.34875e+06
# Name: 9345, dtype: object
# item.Street only: OAKWOOD COURT
# index: 9353
# item: Street       OBSERVATORY GARDENS
# Avg_Price               2.42e+06
# Name: 9353, dtype: object
# item.Street only: OBSERVATORY GARDENS
# index: 9388
# item: Street       OLD COURT PLACE
# Avg_Price          2.395e+06
# Name: 9388, dtype: object
# item.Street only: OLD COURT PLACE
# index: 9449
# item: Street       ONSLOW MEWS WEST
# Avg_Price             2.3e+06
# Name: 9449, dtype: object
# item.Street only: ONSLOW MEWS WEST
# index: 9581
# item: Street       PALACE PLACE
# Avg_Price         2.3e+06
# Name: 9581, dtype: object
# item.Street only: PALACE PLACE
# index: 9610
# item: Street       PANTON STREET
# Avg_Price        2.475e+06
# Name: 9610, dtype: object
# item.Street only: PANTON STREET
# index: 9629
# item: Street       PARK CRESCENT
# Avg_Price         2.44e+06
# Name: 9629, dtype: object
# item.Street only: PARK CRESCENT
# index: 9638
# item: Street        PARK LANE
# Avg_Price    2.2415e+06
# Name: 9638, dtype: object
# item.Street only: PARK LANE
# index: 9659
# item: Street       PARKE ROAD
# Avg_Price    2.2625e+06
# Name: 9659, dtype: object
# item.Street only: PARKE ROAD
# index: 9662
# item: Street       PARKFIELDS
# Avg_Price       2.2e+06
# Name: 9662, dtype: object
# item.Street only: PARKFIELDS
# index: 9699
# item: Street       PARTHENIA ROAD
# Avg_Price       2.20057e+06
# Name: 9699, dtype: object
# item.Street only: PARTHENIA ROAD
# index: 9731
# item: Street       PAVILION ROAD
# Avg_Price          2.2e+06
# Name: 9731, dtype: object
# item.Street only: PAVILION ROAD
# index: 9792
# item: Street       PEMBRIDGE MEWS
# Avg_Price         2.251e+06
# Name: 9792, dtype: object
# item.Street only: PEMBRIDGE MEWS
# index: 9794
# item: Street       PEMBRIDGE ROAD
# Avg_Price           2.4e+06
# Name: 9794, dtype: object
# item.Street only: PEMBRIDGE ROAD
# index: 9803
# item: Street       PEMBROKE STUDIOS
# Avg_Price            2.45e+06
# Name: 9803, dtype: object
# item.Street only: PEMBROKE STUDIOS
# index: 9808
# item: Street       PENCOMBE MEWS
# Avg_Price          2.2e+06
# Name: 9808, dtype: object
# item.Street only: PENCOMBE MEWS
# index: 9888
# item: Street       PETERSHAM PLACE
# Avg_Price            2.3e+06
# Name: 9888, dtype: object
# item.Street only: PETERSHAM PLACE
# index: 9903
# item: Street       PHILLIMORE GARDENS
# Avg_Price           2.48467e+06
# Name: 9903, dtype: object
# item.Street only: PHILLIMORE GARDENS
# index: 9912
# item: Street       PHYSIC PLACE
# Avg_Price         2.5e+06
# Name: 9912, dtype: object
# item.Street only: PHYSIC PLACE
# index: 9950
# item: Street       PITFIELD STREET
# Avg_Price        2.48333e+06
# Name: 9950, dtype: object
# item.Street only: PITFIELD STREET
# index: 10160
# item: Street       PRINCES GATE
# Avg_Price     2.40333e+06
# Name: 10160, dtype: object
# item.Street only: PRINCES GATE
# index: 10188
# item: Street       PRIORY ROAD
# Avg_Price    2.24826e+06
# Name: 10188, dtype: object
# item.Street only: PRIORY ROAD
# index: 10199
# item: Street       PROTHERO GARDENS
# Avg_Price          2.2025e+06
# Name: 10199, dtype: object
# item.Street only: PROTHERO GARDENS
# index: 10252
# item: Street       QUARRENDON STREET
# Avg_Price          2.43775e+06
# Name: 10252, dtype: object
# item.Street only: QUARRENDON STREET
# index: 10285
# item: Street       QUEENS GATE TERRACE
# Avg_Price            2.39944e+06
# Name: 10285, dtype: object
# item.Street only: QUEENS GATE TERRACE
# index: 10339
# item: Street       RADSTOCK STREET
# Avg_Price         2.2175e+06
# Name: 10339, dtype: object
# item.Street only: RADSTOCK STREET
# index: 10384
# item: Street       RANELAGH AVENUE
# Avg_Price            2.3e+06
# Name: 10384, dtype: object
# item.Street only: RANELAGH AVENUE
# index: 10492
# item: Street       REDCLIFFE ROAD
# Avg_Price       2.44875e+06
# Name: 10492, dtype: object
# item.Street only: REDCLIFFE ROAD
# index: 10517
# item: Street       REEVES MEWS
# Avg_Price       2.45e+06
# Name: 10517, dtype: object
# item.Street only: REEVES MEWS
# index: 10574
# item: Street       RHEIDOL MEWS
# Avg_Price        2.31e+06
# Name: 10574, dtype: object
# item.Street only: RHEIDOL MEWS
# index: 10629
# item: Street       RINGWOOD AVENUE
# Avg_Price          2.275e+06
# Name: 10629, dtype: object
# item.Street only: RINGWOOD AVENUE
# index: 10710
# item: Street       RODERICK ROAD
# Avg_Price          2.4e+06
# Name: 10710, dtype: object
# item.Street only: RODERICK ROAD
# index: 10767
# item: Street       ROPEMAKERS FIELDS
# Avg_Price              2.5e+06
# Name: 10767, dtype: object
# item.Street only: ROPEMAKERS FIELDS
# index: 10882
# item: Street       ROYAL CRESCENT
# Avg_Price       2.34833e+06
# Name: 10882, dtype: object
# item.Street only: ROYAL CRESCENT
# index: 10888
# item: Street       ROYAL HILL
# Avg_Price    2.2525e+06
# Name: 10888, dtype: object
# item.Street only: ROYAL HILL
# index: 10945
# item: Street       RUSSELL GARDENS MEWS
# Avg_Price                 2.3e+06
# Name: 10945, dtype: object
# item.Street only: RUSSELL GARDENS MEWS
# index: 11193
# item: Street       SETTLES STREET
# Avg_Price        2.4875e+06
# Name: 11193, dtype: object
# item.Street only: SETTLES STREET
# index: 11268
# item: Street       SHELDON AVENUE
# Avg_Price       2.34954e+06
# Name: 11268, dtype: object
# item.Street only: SHELDON AVENUE
# index: 11502
# item: Street       SOUTH END ROW
# Avg_Price         2.47e+06
# Name: 11502, dtype: object
# item.Street only: SOUTH END ROW
# index: 11579
# item: Street       SOUTHWOOD LAWN ROAD
# Avg_Price               2.35e+06
# Name: 11579, dtype: object
# item.Street only: SOUTHWOOD LAWN ROAD
# index: 11582
# item: Street       SOVEREIGN PARK
# Avg_Price           2.5e+06
# Name: 11582, dtype: object
# item.Street only: SOVEREIGN PARK
# index: 11800
# item: Street       ST MARGARETS CRESCENT
# Avg_Price               2.2165e+06
# Name: 11800, dtype: object
# item.Street only: ST MARGARETS CRESCENT
# index: 11836
# item: Street       ST OSWALDS PLACE
# Avg_Price            2.25e+06
# Name: 11836, dtype: object
# item.Street only: ST OSWALDS PLACE
# index: 11856
# item: Street       ST PETERS SQUARE
# Avg_Price         2.46873e+06
# Name: 11856, dtype: object
# item.Street only: ST PETERS SQUARE
# index: 11893
# item: Street       STAFFORD TERRACE
# Avg_Price           2.355e+06
# Name: 11893, dtype: object
# item.Street only: STAFFORD TERRACE
# index: 12233
# item: Street       SUTHERLAND PLACE
# Avg_Price           2.456e+06
# Name: 12233, dtype: object
# item.Street only: SUTHERLAND PLACE
# index: 12295
# item: Street       SYDNEY STREET
# Avg_Price      2.24083e+06
# Name: 12295, dtype: object
# item.Street only: SYDNEY STREET
# index: 12437
# item: Street       THAMES BANK
# Avg_Price        2.4e+06
# Name: 12437, dtype: object
# item.Street only: THAMES BANK
# index: 12499
# item: Street       THE HEXAGON
# Avg_Price      2.335e+06
# Name: 12499, dtype: object
# item.Street only: THE HEXAGON
# index: 12779
# item: Street       TREDEGAR SQUARE
# Avg_Price        2.43667e+06
# Name: 12779, dtype: object
# item.Street only: TREDEGAR SQUARE
# index: 12842
# item: Street       TRINITY STREET
# Avg_Price        2.3175e+06
# Name: 12842, dtype: object
# item.Street only: TRINITY STREET
# index: 12992
# item: Street       UPPER HAMPSTEAD WALK
# Avg_Price                 2.5e+06
# Name: 12992, dtype: object
# item.Street only: UPPER HAMPSTEAD WALK
# index: 13254
# item: Street       WALPOLE GARDENS
# Avg_Price         2.3035e+06
# Name: 13254, dtype: object
# item.Street only: WALPOLE GARDENS
# index: 13256
# item: Street       WALPOLE STREET
# Avg_Price        2.2425e+06
# Name: 13256, dtype: object
# item.Street only: WALPOLE STREET
# index: 13330
# item: Street       WARWICK SQUARE
# Avg_Price       2.43227e+06
# Name: 13330, dtype: object
# item.Street only: WARWICK SQUARE
# index: 13429
# item: Street       WELBECK WAY
# Avg_Price      2.267e+06
# Name: 13429, dtype: object
# item.Street only: WELBECK WAY
# index: 13441
# item: Street       WELLESLEY TERRACE
# Avg_Price             2.41e+06
# Name: 13441, dtype: object
# item.Street only: WELLESLEY TERRACE
# index: 13452
# item: Street       WELLINGTON STREET
# Avg_Price          2.29316e+06
# Name: 13452, dtype: object
# item.Street only: WELLINGTON STREET
# index: 13584
# item: Street       WESTMORELAND PLACE
# Avg_Price               2.3e+06
# Name: 13584, dtype: object
# item.Street only: WESTMORELAND PLACE
# index: 13691
# item: Street       WHITFIELD STREET
# Avg_Price           2.451e+06
# Name: 13691, dtype: object
# item.Street only: WHITFIELD STREET
# index: 13736
# item: Street       WILFRED STREET
# Avg_Price       2.41054e+06
# Name: 13736, dtype: object
# item.Street only: WILFRED STREET
# index: 13762
# item: Street       WILLOW BRIDGE ROAD
# Avg_Price             2.425e+06
# Name: 13762, dtype: object
# item.Street only: WILLOW BRIDGE ROAD
# index: 13782
# item: Street       WILSON STREET
# Avg_Price       2.2575e+06
# Name: 13782, dtype: object
# item.Street only: WILSON STREET
# index: 13811
# item: Street       WINCHENDON ROAD
# Avg_Price           2.35e+06
# Name: 13811, dtype: object
# item.Street only: WINCHENDON ROAD
# index: 13848
# item: Street       WINGATE ROAD
# Avg_Price      2.2064e+06
# Name: 13848, dtype: object
# item.Street only: WINGATE ROAD

# %%
geolocator = Nominatim()
# Out:
# /usr/local/lib/python3.7/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
df_affordable['city_coord'] = df_affordable['Street'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_affordable
# Out:
#                    Street  Avg_Price                          city_coord
# 196         ALBION SQUARE  2450000.0  (-41.27375755, 173.28939323910353)
# 390           ANHALT ROAD  2435000.0             (29.805547, -98.475534)
# 405       ANSDELL TERRACE  2250000.0            (51.5000051, -0.1891537)
# 422       APPLEGARTH ROAD  2400000.0            (40.271236, -74.4711104)
# 857       BARONSMEAD ROAD  2375000.0             (51.4773147, -0.239457)
# ...                   ...        ...                                 ...
# 13736      WILFRED STREET  2410538.5           (46.4369189, -63.8655639)
# 13762  WILLOW BRIDGE ROAD  2425000.0            (51.5431088, -0.0955079)
# 13782       WILSON STREET  2257500.0   (45.7004857, -121.52187527526078)
# 13811     WINCHENDON ROAD  2350000.0             (42.645331, -71.954714)
# 13848        WINGATE ROAD  2206400.0            (54.7175864, -1.3976575)
#
# [159 rows x 3 columns]

# %%
df_affordable[['Latitude', 'Longitude']] = df_affordable['city_coord'].apply(pd.Series)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
df_affordable
# Out:
#                    Street  Avg_Price  ...   Latitude   Longitude
# 196         ALBION SQUARE  2450000.0  ... -41.273758  173.289393
# 390           ANHALT ROAD  2435000.0  ...  29.805547  -98.475534
# 405       ANSDELL TERRACE  2250000.0  ...  51.500005   -0.189154
# 422       APPLEGARTH ROAD  2400000.0  ...  40.271236  -74.471110
# 857       BARONSMEAD ROAD  2375000.0  ...  51.477315   -0.239457
# ...                   ...        ...  ...        ...         ...
# 13736      WILFRED STREET  2410538.5  ...  46.436919  -63.865564
# 13762  WILLOW BRIDGE ROAD  2425000.0  ...  51.543109   -0.095508
# 13782       WILSON STREET  2257500.0  ...  45.700486 -121.521875
# 13811     WINCHENDON ROAD  2350000.0  ...  42.645331  -71.954714
# 13848        WINGATE ROAD  2206400.0  ...  54.717586   -1.397657
#
# [159 rows x 5 columns]

# %%
df = df_affordable.drop(columns=['city_coord'])

# %%
df
# Out:
#                    Street  Avg_Price   Latitude   Longitude
# 196         ALBION SQUARE  2450000.0 -41.273758  173.289393
# 390           ANHALT ROAD  2435000.0  29.805547  -98.475534
# 405       ANSDELL TERRACE  2250000.0  51.500005   -0.189154
# 422       APPLEGARTH ROAD  2400000.0  40.271236  -74.471110
# 857       BARONSMEAD ROAD  2375000.0  51.477315   -0.239457
# ...                   ...        ...        ...         ...
# 13736      WILFRED STREET  2410538.5  46.436919  -63.865564
# 13762  WILLOW BRIDGE ROAD  2425000.0  51.543109   -0.095508
# 13782       WILSON STREET  2257500.0  45.700486 -121.521875
# 13811     WINCHENDON ROAD  2350000.0  42.645331  -71.954714
# 13848        WINGATE ROAD  2206400.0  54.717586   -1.397657
#
# [159 rows x 4 columns]

# %%
address = 'London, UK'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of London City are {}, {}.'.format(latitude, longitude))
# Out:
# /usr/local/lib/python3.7/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of London City are 51.5073219, -0.1276474.

# %%
# create map of London using latitude and longitude values
map_london = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, price, street in zip(df['Latitude'], df['Longitude'], df['Avg_Price'], df['Street']):
    label = '{}, {}'.format(street, price)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_london)  
    
map_london
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_eec4cd1f6b7e4fa3b21b8e00312248b2%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eec4cd1f6b7e4fa3b21b8e00312248b2%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_eec4cd1f6b7e4fa3b21b8e00312248b2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_eec4cd1f6b7e4fa3b21b8e00312248b2%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_acf4e9e4206d40c591a16def2daaa54e%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %%
#Define Foursquare Credentials and Version

CLIENT_ID = 'KI3TR0QO4JOKMFELOMF3WSOOI3HFNBF5YLW354MYWBKDHEX3' # Foursquare ID
CLIENT_SECRET = 'QF4ZBLJRBV4BQX52DVWUPEHJ14A2UJABPCZARZQZYTKIISUD' # Foursquare Secret
VERSION = '20181206' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KI3TR0QO4JOKMFELOMF3WSOOI3HFNBF5YLW354MYWBKDHEX3
# CLIENT_SECRET:QF4ZBLJRBV4BQX52DVWUPEHJ14A2UJABPCZARZQZYTKIISUD

# %% [markdown]
# We can now proceed to the Modeling phase. We will analyze neighborhoods to recommend real estates where home buyers can make a real estate investment. We will then recommend profitable venues according to amenities and essential facilities surrounding such venues i.e. elementary schools, high schools, hospitals & grocery stores.

# %% [markdown]
# 4.**Modeling**
#
# After exploring the dataset and gaining insights into it, we are ready to use the clustering methodology to analyze real estates. We will use the k-means clustering technique as it is fast and efficient in terms of computational cost, is highly flexible to account for mutations in real estate market in London and is accurate.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Street', 
                  'Street Latitude', 
                  'Street Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Run the above function on each location and create a new dataframe called location_venues and display it.
location_venues = getNearbyVenues(names=df['Street'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# ALBION SQUARE
# ANHALT ROAD
# ANSDELL TERRACE
# APPLEGARTH ROAD
# BARONSMEAD ROAD
# BEAUCLERC ROAD
# BELVEDERE DRIVE
# BICKENHALL STREET
# BIRCHLANDS AVENUE
# BRAMPTON GROVE
# BRIARDALE GARDENS
# BROOKWAY
# BURY WALK
# CALLCOTT STREET
# CAMPDEN HILL ROAD
# CAMPION ROAD
# CANNING PLACE
# CARLISLE ROAD
# CARLTON GARDENS
# CARLYLE COURT
# CHALCOT SQUARE
# CHARLES LANE
# CHELSEA CRESCENT
# CHESTER CLOSE NORTH
# CHEYNE COURT
# CHEYNE ROW
# CHISWICK MALL
# CITY ROAD
# CLARENDON STREET
# CLONCURRY STREET
# COLBECK MEWS
# COLLEGE CRESCENT
# CORNWALL TERRACE MEWS
# COURT LANE GARDENS
# CRESCENT GROVE
# DALEBURY ROAD
# DEWHURST ROAD
# DORIA ROAD
# DOWNSHIRE HILL
# DUCHESS WALK
# ECCLESTON SQUARE MEWS
# EGBERT STREET
# EGERTON PLACE
# ELM PARK ROAD
# FLORAL STREET
# FRANK DIXON WAY
# FULTON MEWS
# GERARD ROAD
# GERRARD ROAD
# GIRDLERS ROAD
# GLOUCESTER CRESCENT
# GORDON PLACE
# GRAFTON SQUARE
# GRAHAM TERRACE
# HARMAN DRIVE
# HARRIS STREET
# HAVANNAH STREET
# HAZLEWELL ROAD
# HEREFORD MEWS
# HERONDALE AVENUE
# HIGHWOOD HILL
# HILLGATE PLACE
# HOLLYCROFT AVENUE
# HOLLYWOOD MEWS
# HONEYWELL ROAD
# HORTENSIA ROAD
# HOXTON SQUARE
# HUNTER ROAD
# JACKSONS LANE
# JOHN STREET
# KINNERTON STREET
# KNARESBOROUGH PLACE
# KNOX STREET
# LANCASTER MEWS
# LANSDOWNE ROAD
# LATIMER INDUSTRIAL ESTATE
# LAXTON PLACE
# LINCOLN AVENUE
# LINGFIELD ROAD
# LISSON STREET
# LIVERPOOL GROVE
# LONGWOOD DRIVE
# LONSDALE SQUARE
# MANSFIELD STREET
# MAZE HILL
# MIDDLESEX PASSAGE
# MONTPELIER AVENUE
# MONTPELIER WALK
# MULTON ROAD
# MUNDEN STREET
# NORFOLK CRESCENT
# NORTH CIRCULAR ROAD
# NOTTINGHAM STREET
# OAKLEY STREET
# OAKWOOD COURT
# OBSERVATORY GARDENS
# OLD COURT PLACE
# ONSLOW MEWS WEST
# PALACE PLACE
# PANTON STREET
# PARK CRESCENT
# PARK LANE
# PARKE ROAD
# PARKFIELDS
# PARTHENIA ROAD
# PAVILION ROAD
# PEMBRIDGE MEWS
# PEMBRIDGE ROAD
# PEMBROKE STUDIOS
# PENCOMBE MEWS
# PETERSHAM PLACE
# PHILLIMORE GARDENS
# PHYSIC PLACE
# PITFIELD STREET
# PRINCES GATE
# PRIORY ROAD
# PROTHERO GARDENS
# QUARRENDON STREET
# QUEENS GATE TERRACE
# RADSTOCK STREET
# RANELAGH AVENUE
# REDCLIFFE ROAD
# REEVES MEWS
# RHEIDOL MEWS
# RINGWOOD AVENUE
# RODERICK ROAD
# ROPEMAKERS FIELDS
# ROYAL CRESCENT
# ROYAL HILL
# RUSSELL GARDENS MEWS
# SETTLES STREET
# SHELDON AVENUE
# SOUTH END ROW
# SOUTHWOOD LAWN ROAD
# SOVEREIGN PARK
# ST MARGARETS CRESCENT
# ST OSWALDS PLACE
# ST PETERS SQUARE
# STAFFORD TERRACE
# SUTHERLAND PLACE
# SYDNEY STREET
# THAMES BANK
# THE HEXAGON
# TREDEGAR SQUARE
# TRINITY STREET
# UPPER HAMPSTEAD WALK
# WALPOLE GARDENS
# WALPOLE STREET
# WARWICK SQUARE
# WELBECK WAY
# WELLESLEY TERRACE
# WELLINGTON STREET
# WESTMORELAND PLACE
# WHITFIELD STREET
# WILFRED STREET
# WILLOW BRIDGE ROAD
# WILSON STREET
# WINCHENDON ROAD
# WINGATE ROAD

# %%
location_venues
# Out:
#              Street  Street Latitude  ...  Venue Longitude           Venue Category
# 0     ALBION SQUARE       -41.273758  ...       173.287364                      Bar
# 1     ALBION SQUARE       -41.273758  ...       173.286530        Indian Restaurant
# 2     ALBION SQUARE       -41.273758  ...       173.291383                     Park
# 3     ALBION SQUARE       -41.273758  ...       173.285517                     Café
# 4     ALBION SQUARE       -41.273758  ...       173.286317  New American Restaurant
# ...             ...              ...  ...              ...                      ...
# 4984  WILSON STREET        45.700486  ...      -121.524445       Mexican Restaurant
# 4985  WILSON STREET        45.700486  ...      -121.523560                      Bar
# 4986  WILSON STREET        45.700486  ...      -121.524078            Grocery Store
# 4987  WILSON STREET        45.700486  ...      -121.523032              Gas Station
# 4988  WILSON STREET        45.700486  ...      -121.524643           Breakfast Spot
#
# [4989 rows x 7 columns]

# %%
location_venues.groupby('Street').count()
# Out:
#                     Street Latitude  ...  Venue Category
# Street                               ...
# ALBION SQUARE                    26  ...              26
# ANSDELL TERRACE                  66  ...              66
# APPLEGARTH ROAD                   5  ...               5
# BARONSMEAD ROAD                  16  ...              16
# BEAUCLERC ROAD                    2  ...               2
# ...                             ...  ...             ...
# WESTMORELAND PLACE               15  ...              15
# WHITFIELD STREET                100  ...             100
# WILFRED STREET                    2  ...               2
# WILLOW BRIDGE ROAD               23  ...              23
# WILSON STREET                    17  ...              17
#
# [144 rows x 6 columns]

# %%
# get the List of Unique Categories
print('There are {} uniques categories.'.format(len(location_venues['Venue Category'].unique())))
# Out:
# There are 348 uniques categories.

# %%
location_venues.shape
# Out:
# (4989, 7)

# %%
# one hot encoding
venues_onehot = pd.get_dummies(location_venues[['Venue Category']], prefix="", prefix_sep="")

# add street column back to dataframe
venues_onehot['Street'] = location_venues['Street'] 

# move street column to the first column
fixed_columns = [venues_onehot.columns[-1]] + list(venues_onehot.columns[:-1])

#fixed_columns
venues_onehot = venues_onehot[fixed_columns]

venues_onehot.head()
# Out:
#           Street  ATM  ...  Yoga Studio  Zoo Exhibit
# 0  ALBION SQUARE    0  ...            0            0
# 1  ALBION SQUARE    0  ...            0            0
# 2  ALBION SQUARE    0  ...            0            0
# 3  ALBION SQUARE    0  ...            0            0
# 4  ALBION SQUARE    0  ...            0            0
#
# [5 rows x 349 columns]

# %%
london_grouped = venues_onehot.groupby('Street').mean().reset_index()
london_grouped
# Out:
#                  Street       ATM  ...  Yoga Studio  Zoo Exhibit
# 0         ALBION SQUARE  0.000000  ...          0.0          0.0
# 1       ANSDELL TERRACE  0.000000  ...          0.0          0.0
# 2       APPLEGARTH ROAD  0.000000  ...          0.0          0.0
# 3       BARONSMEAD ROAD  0.000000  ...          0.0          0.0
# 4        BEAUCLERC ROAD  0.000000  ...          0.0          0.0
# ..                  ...       ...  ...          ...          ...
# 139  WESTMORELAND PLACE  0.000000  ...          0.0          0.0
# 140    WHITFIELD STREET  0.000000  ...          0.0          0.0
# 141      WILFRED STREET  0.000000  ...          0.0          0.0
# 142  WILLOW BRIDGE ROAD  0.000000  ...          0.0          0.0
# 143       WILSON STREET  0.058824  ...          0.0          0.0
#
# [144 rows x 349 columns]

# %%
london_grouped.shape
# Out:
# (144, 349)

# %%
# What are the top 5 venues/facilities nearby profitable real estate investments?#

num_top_venues = 5

for hood in london_grouped['Street']:
    print("----"+hood+"----")
    temp = london_grouped[london_grouped['Street'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----ALBION SQUARE----
#                venue  freq
# 0               Café  0.19
# 1         Restaurant  0.08
# 2                Bar  0.08
# 3  Indian Restaurant  0.08
# 4                Pub  0.08
#
#
# ----ANSDELL TERRACE----
#                 venue  freq
# 0               Hotel  0.08
# 1          Restaurant  0.06
# 2   Indian Restaurant  0.06
# 3           Juice Bar  0.06
# 4  Italian Restaurant  0.05
#
#
# ----APPLEGARTH ROAD----
#                   venue  freq
# 0     Convenience Store   0.4
# 1      Storage Facility   0.2
# 2  Fast Food Restaurant   0.2
# 3            Donut Shop   0.2
# 4                   ATM   0.0
#
#
# ----BARONSMEAD ROAD----
#                venue  freq
# 0  Food & Drink Shop  0.12
# 1                Pub  0.06
# 2  Convenience Store  0.06
# 3    Thai Restaurant  0.06
# 4               Park  0.06
#
#
# ----BEAUCLERC ROAD----
#                    venue  freq
# 0             Food Truck   0.5
# 1              Locksmith   0.5
# 2                    ATM   0.0
# 3  Outdoors & Recreation   0.0
# 4              Pawn Shop   0.0
#
#
# ----BELVEDERE DRIVE----
#                    venue  freq
# 0      Convenience Store   1.0
# 1                    ATM   0.0
# 2  Outdoors & Recreation   0.0
# 3       Pedestrian Plaza   0.0
# 4              Pawn Shop   0.0
#
#
# ----BICKENHALL STREET----
#          venue  freq
# 0   Restaurant  0.05
# 1         Café  0.03
# 2  Coffee Shop  0.03
# 3       Museum  0.03
# 4        Hotel  0.03
#
#
# ----BIRCHLANDS AVENUE----
#                   venue  freq
# 0                   Pub   0.2
# 1               Brewery   0.1
# 2     French Restaurant   0.1
# 3  Gym / Fitness Center   0.1
# 4                  Lake   0.1
#
#
# ----BRAMPTON GROVE----
#                        venue  freq
# 0                       Lake   0.5
# 1  Middle Eastern Restaurant   0.5
# 2      Performing Arts Venue   0.0
# 3                  Pawn Shop   0.0
# 4                Pastry Shop   0.0
#
#
# ----BRIARDALE GARDENS----
#                   venue  freq
# 0        Breakfast Spot   0.2
# 1  Gym / Fitness Center   0.2
# 2         Grocery Store   0.2
# 3                  Park   0.2
# 4           Coffee Shop   0.2
#
#
# ----BURY WALK----
#                 venue  freq
# 0  English Restaurant  0.14
# 1         Supermarket  0.14
# 2         Dry Cleaner  0.07
# 3                Café  0.07
# 4                Park  0.07
#
#
# ----CALLCOTT STREET----
#            venue  freq
# 0            Pub  0.13
# 1    Yoga Studio  0.04
# 2          Hotel  0.04
# 3           Park  0.04
# 4  Grocery Store  0.04
#
#
# ----CAMPDEN HILL ROAD----
#             venue  freq
# 0             Pub  0.10
# 1   Grocery Store  0.06
# 2  Sandwich Place  0.04
# 3     Coffee Shop  0.04
# 4     Yoga Studio  0.04
#
#
# ----CAMPION ROAD----
#                     venue  freq
# 0  Furniture / Home Store  0.25
# 1                  Bakery  0.25
# 2    Fast Food Restaurant  0.25
# 3             Coffee Shop  0.25
# 4    Pakistani Restaurant  0.00
#
#
# ----CANNING PLACE----
#                       venue  freq
# 0                     Hotel  0.17
# 1        Italian Restaurant  0.09
# 2  Mediterranean Restaurant  0.06
# 3                       Pub  0.06
# 4         French Restaurant  0.06
#
#
# ----CARLISLE ROAD----
#                    venue  freq
# 0             Campground  0.50
# 1        Bed & Breakfast  0.25
# 2                   Café  0.25
# 3  Outdoors & Recreation  0.00
# 4              Pawn Shop  0.00
#
#
# ----CARLTON GARDENS----
#                  venue  freq
# 0   Italian Restaurant  0.22
# 1  Japanese Restaurant  0.05
# 2                Hotel  0.05
# 3         Dessert Shop  0.05
# 4       Ice Cream Shop  0.03
#
#
# ----CARLYLE COURT----
#                    venue  freq
# 0                   Farm   1.0
# 1                    ATM   0.0
# 2  Outdoors & Recreation   0.0
# 3              Pawn Shop   0.0
# 4            Pastry Shop   0.0
#
#
# ----CHALCOT SQUARE----
#                 venue  freq
# 0                 Pub  0.08
# 1                Café  0.08
# 2  Italian Restaurant  0.08
# 3         Coffee Shop  0.06
# 4                 Bar  0.04
#
#
# ----CHARLES LANE----
#                  venue  freq
# 0  Sporting Goods Shop   0.2
# 1          Gas Station   0.2
# 2          Pizza Place   0.2
# 3    Convenience Store   0.2
# 4           Toll Booth   0.2
#
#
# ----CHELSEA CRESCENT----
#         venue  freq
# 0  Restaurant  0.08
# 1        Café  0.08
# 2       Hotel  0.08
# 3   Gastropub  0.04
# 4         Spa  0.04
#
#
# ----CHESTER CLOSE NORTH----
#                   venue  freq
# 0                Garden  0.13
# 1                  Café  0.09
# 2  Gym / Fitness Center  0.09
# 3          Cocktail Bar  0.09
# 4    Mexican Restaurant  0.04
#
#
# ----CHEYNE COURT----
#                 venue  freq
# 0                 Pub  0.11
# 1                Café  0.11
# 2  English Restaurant  0.04
# 3   French Restaurant  0.04
# 4       Grocery Store  0.04
#
#
# ----CHEYNE ROW----
#                 venue  freq
# 0                Café  0.08
# 1  Italian Restaurant  0.07
# 2                 Pub  0.05
# 3        Burger Joint  0.03
# 4         Pizza Place  0.03
#
#
# ----CHISWICK MALL----
#              venue  freq
# 0              Pub  0.29
# 1       Art Museum  0.14
# 2        Reservoir  0.14
# 3        Gift Shop  0.14
# 4  Harbor / Marina  0.14
#
#
# ----CITY ROAD----
#             venue  freq
# 0             Pub  0.32
# 1     Coffee Shop  0.12
# 2  Sandwich Place  0.08
# 3     Art Gallery  0.08
# 4       BBQ Joint  0.04
#
#
# ----CLARENDON STREET----
#                  venue  freq
# 0        Train Station  0.25
# 1        Historic Site  0.25
# 2  Monument / Landmark  0.25
# 3                Hotel  0.25
# 4                  ATM  0.00
#
#
# ----CLONCURRY STREET----
#             venue  freq
# 0            Café  0.16
# 1            Park  0.10
# 2  Soccer Stadium  0.06
# 3     Coffee Shop  0.06
# 4             Bar  0.06
#
#
# ----COLBECK MEWS----
#                 venue  freq
# 0               Hotel  0.23
# 1                 Pub  0.06
# 2              Garden  0.05
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# ----CORNWALL TERRACE MEWS----
#          venue  freq
# 0         Café  0.09
# 1       Garden  0.09
# 2  Coffee Shop  0.07
# 3         Park  0.07
# 4       Museum  0.07
#
#
# ----COURT LANE GARDENS----
#                venue  freq
# 0                Pub  0.15
# 1      Grocery Store  0.15
# 2        Art Gallery  0.08
# 3               Café  0.08
# 4  Food & Drink Shop  0.08
#
#
# ----CRESCENT GROVE----
#                   venue  freq
# 0                 Hotel   1.0
# 1                   ATM   0.0
# 2  Outdoor Supply Store   0.0
# 3             Pawn Shop   0.0
# 4           Pastry Shop   0.0
#
#
# ----DALEBURY ROAD----
#                        venue  freq
# 0  Middle Eastern Restaurant  0.11
# 1                   Bus Stop  0.11
# 2                Gas Station  0.11
# 3                       Café  0.11
# 4                 Playground  0.11
#
#
# ----DEWHURST ROAD----
#                 venue  freq
# 0                 Pub  0.14
# 1               Hotel  0.10
# 2           Gastropub  0.07
# 3  Italian Restaurant  0.07
# 4   Indian Restaurant  0.07
#
#
# ----DORIA ROAD----
#                 venue  freq
# 0  Italian Restaurant  0.11
# 1                Café  0.08
# 2              Bakery  0.06
# 3                 Pub  0.06
# 4         Coffee Shop  0.06
#
#
# ----DOWNSHIRE HILL----
#                 venue  freq
# 0                Café  0.16
# 1                 Pub  0.14
# 2  Italian Restaurant  0.05
# 3         Coffee Shop  0.05
# 4     Thai Restaurant  0.05
#
#
# ----DUCHESS WALK----
#                 venue  freq
# 0         Coffee Shop  0.06
# 1                 Bar  0.06
# 2                 Pub  0.06
# 3        Cocktail Bar  0.05
# 4  Italian Restaurant  0.04
#
#
# ----ECCLESTON SQUARE MEWS----
#                 venue  freq
# 0               Hotel  0.10
# 1                 Pub  0.08
# 2  Italian Restaurant  0.06
# 3                Café  0.05
# 4         Coffee Shop  0.05
#
#
# ----EGBERT STREET----
#                 venue  freq
# 0         Coffee Shop  0.08
# 1                Café  0.08
# 2                 Pub  0.06
# 3  Italian Restaurant  0.04
# 4         Pizza Place  0.04
#
#
# ----EGERTON PLACE----
#                  venue  freq
# 0                 Café  0.11
# 1   Italian Restaurant  0.10
# 2             Boutique  0.05
# 3  Japanese Restaurant  0.04
# 4                Hotel  0.04
#
#
# ----ELM PARK ROAD----
#                   venue  freq
# 0      Sushi Restaurant   0.2
# 1  Gym / Fitness Center   0.2
# 2    Mexican Restaurant   0.2
# 3     Convenience Store   0.2
# 4          Soccer Field   0.2
#
#
# ----FLORAL STREET----
#                 venue  freq
# 0          Food Truck  0.33
# 1             Brewery  0.17
# 2  Mexican Restaurant  0.17
# 3       Movie Theater  0.17
# 4      Breakfast Spot  0.17
#
#
# ----FRANK DIXON WAY----
#                   venue  freq
# 0  Gym / Fitness Center  0.11
# 1                  Café  0.11
# 2            Restaurant  0.11
# 3             Gastropub  0.11
# 4                  Lake  0.11
#
#
# ----FULTON MEWS----
#                 venue  freq
# 0               Hotel  0.16
# 1                 Pub  0.06
# 2         Coffee Shop  0.06
# 3  Chinese Restaurant  0.05
# 4              Garden  0.04
#
#
# ----GERARD ROAD----
#                         venue  freq
# 0              Scenic Lookout  0.25
# 1           Convenience Store  0.25
# 2  Construction & Landscaping  0.25
# 3           Fish & Chips Shop  0.25
# 4                         ATM  0.00
#
#
# ----GERRARD ROAD----
#                   venue  freq
# 0                   Pub  0.33
# 1  Fast Food Restaurant  0.33
# 2           Supermarket  0.33
# 3  Outdoor Supply Store  0.00
# 4           Pastry Shop  0.00
#
#
# ----GIRDLERS ROAD----
#                 venue  freq
# 0                 Pub  0.14
# 1           Gastropub  0.05
# 2         Pizza Place  0.05
# 3   Convention Center  0.05
# 4  Italian Restaurant  0.05
#
#
# ----GORDON PLACE----
#                            venue  freq
# 0                     Food Truck  0.17
# 1     Construction & Landscaping  0.17
# 2                  Historic Site  0.17
# 3  Paper / Office Supplies Store  0.17
# 4                   Home Service  0.17
#
#
# ----GRAFTON SQUARE----
#           venue  freq
# 0           Pub  0.10
# 1          Café  0.05
# 2  Burger Joint  0.05
# 3  Cocktail Bar  0.04
# 4   Coffee Shop  0.04
#
#
# ----GRAHAM TERRACE----
#                 venue  freq
# 0              Bakery  0.06
# 1  Italian Restaurant  0.06
# 2         Coffee Shop  0.06
# 3               Hotel  0.04
# 4               Plaza  0.04
#
#
# ----HARMAN DRIVE----
#                    venue  freq
# 0        Photography Lab   1.0
# 1                    ATM   0.0
# 2  Performing Arts Venue   0.0
# 3              Pawn Shop   0.0
# 4            Pastry Shop   0.0
#
#
# ----HARRIS STREET----
#                venue  freq
# 0               Pool   0.5
# 1      Movie Theater   0.5
# 2                ATM   0.0
# 3  Outdoor Sculpture   0.0
# 4        Pastry Shop   0.0
#
#
# ----HAVANNAH STREET----
#                 venue  freq
# 0               Hotel  0.12
# 1   Indian Restaurant  0.09
# 2  Italian Restaurant  0.09
# 3  Turkish Restaurant  0.06
# 4               Diner  0.03
#
#
# ----HAZLEWELL ROAD----
#                   venue  freq
# 0   Japanese Restaurant  0.29
# 1  Gym / Fitness Center  0.14
# 2             Gastropub  0.14
# 3                  Café  0.14
# 4           Coffee Shop  0.14
#
#
# ----HEREFORD MEWS----
#                   venue  freq
# 0                   Pub  0.08
# 1                  Café  0.07
# 2  Gym / Fitness Center  0.04
# 3    Persian Restaurant  0.04
# 4     Indian Restaurant  0.04
#
#
# ----HERONDALE AVENUE----
#                    venue  freq
# 0      French Restaurant  0.50
# 1          Grocery Store  0.25
# 2                   Café  0.25
# 3  Outdoors & Recreation  0.00
# 4              Pawn Shop  0.00
#
#
# ----HIGHWOOD HILL----
#                    venue  freq
# 0     Athletics & Sports   1.0
# 1                    ATM   0.0
# 2  Performing Arts Venue   0.0
# 3              Pawn Shop   0.0
# 4            Pastry Shop   0.0
#
#
# ----HILLGATE PLACE----
#          venue  freq
# 0          Pub  0.10
# 1  Coffee Shop  0.04
# 2  Yoga Studio  0.04
# 3        Hotel  0.04
# 4         Park  0.04
#
#
# ----HOLLYCROFT AVENUE----
#                   venue  freq
# 0                  Café   1.0
# 1                   ATM   0.0
# 2  Outdoor Supply Store   0.0
# 3             Pawn Shop   0.0
# 4           Pastry Shop   0.0
#
#
# ----HOLLYWOOD MEWS----
#                   venue  freq
# 0    Italian Restaurant  0.11
# 1                Garden  0.07
# 2                Bakery  0.07
# 3  Gym / Fitness Center  0.07
# 4                   Pub  0.04
#
#
# ----HONEYWELL ROAD----
#                venue  freq
# 0                Pub  0.23
# 1               Café  0.23
# 2       Antique Shop  0.08
# 3  French Restaurant  0.08
# 4         Steakhouse  0.08
#
#
# ----HORTENSIA ROAD----
#                    venue  freq
# 0    Arts & Crafts Store   1.0
# 1                    ATM   0.0
# 2  Performing Arts Venue   0.0
# 3              Pawn Shop   0.0
# 4            Pastry Shop   0.0
#
#
# ----HOXTON SQUARE----
#           venue  freq
# 0   Coffee Shop  0.09
# 1           Pub  0.05
# 2  Cocktail Bar  0.05
# 3   Art Gallery  0.04
# 4         Hotel  0.04
#
#
# ----JACKSONS LANE----
#                 venue  freq
# 0                 Pub  0.35
# 1               Trail  0.06
# 2       Deli / Bodega  0.06
# 3  Seafood Restaurant  0.06
# 4                Café  0.06
#
#
# ----JOHN STREET----
#                            venue  freq
# 0            Austrian Restaurant  0.08
# 1             Chinese Restaurant  0.08
# 2                      Irish Pub  0.04
# 3                       Bus Stop  0.04
# 4  Paper / Office Supplies Store  0.04
#
#
# ----KINNERTON STREET----
#                 venue  freq
# 0               Hotel  0.12
# 1                Café  0.07
# 2            Boutique  0.07
# 3               Plaza  0.04
# 4  Italian Restaurant  0.04
#
#
# ----KNARESBOROUGH PLACE----
#                 venue  freq
# 0               Hotel  0.29
# 1                 Pub  0.07
# 2  Italian Restaurant  0.06
# 3              Garden  0.04
# 4         Coffee Shop  0.04
#
#
# ----LANCASTER MEWS----
#          venue  freq
# 0        Hotel  0.22
# 1          Pub  0.08
# 2  Coffee Shop  0.08
# 3         Café  0.08
# 4       Garden  0.06
#
#
# ----LANSDOWNE ROAD----
#                venue  freq
# 0              Hotel  0.15
# 1               Café  0.15
# 2          Gastropub  0.07
# 3                Pub  0.07
# 4  Fish & Chips Shop  0.04
#
#
# ----LATIMER INDUSTRIAL ESTATE----
#                   venue  freq
# 0  Gym / Fitness Center  0.21
# 1          Soccer Field  0.14
# 2                  Park  0.14
# 3                   Pub  0.07
# 4            Playground  0.07
#
#
# ----LAXTON PLACE----
#                venue  freq
# 0  Indian Restaurant  0.09
# 1                Pub  0.08
# 2        Coffee Shop  0.08
# 3              Plaza  0.04
# 4               Café  0.03
#
#
# ----LINCOLN AVENUE----
#              venue  freq
# 0    Bowling Green  0.25
# 1  Automotive Shop  0.25
# 2    Auto Workshop  0.25
# 3             Park  0.25
# 4              ATM  0.00
#
#
# ----LINGFIELD ROAD----
#                         venue  freq
# 0                         Pub  0.25
# 1  Construction & Landscaping  0.25
# 2               Grocery Store  0.25
# 3                        Park  0.25
# 4                         ATM  0.00
#
#
# ----LISSON STREET----
#                        venue  freq
# 0             Sandwich Place  0.07
# 1                        Pub  0.07
# 2                Coffee Shop  0.07
# 3  Middle Eastern Restaurant  0.05
# 4                       Café  0.03
#
#
# ----LIVERPOOL GROVE----
#                 venue  freq
# 0                Café  0.17
# 1        Dessert Shop  0.03
# 2     Thai Restaurant  0.03
# 3              Bakery  0.03
# 4  Falafel Restaurant  0.03
#
#
# ----LONSDALE SQUARE----
#                       venue  freq
# 0                       Pub  0.10
# 1                 Gastropub  0.06
# 2  Mediterranean Restaurant  0.06
# 3         French Restaurant  0.06
# 4    Furniture / Home Store  0.05
#
#
# ----MANSFIELD STREET----
#          venue  freq
# 0          Pub  0.25
# 1          Bar  0.17
# 2         Café  0.17
# 3          Gym  0.08
# 4  Pizza Place  0.08
#
#
# ----MIDDLESEX PASSAGE----
#                   venue  freq
# 0    Italian Restaurant  0.07
# 1  Gym / Fitness Center  0.06
# 2              Wine Bar  0.06
# 3           Coffee Shop  0.06
# 4        Sandwich Place  0.04
#
#
# ----MONTPELIER AVENUE----
#             venue  freq
# 0             Pub   0.2
# 1     Supermarket   0.2
# 2   Grocery Store   0.2
# 3  Discount Store   0.2
# 4           Hotel   0.2
#
#
# ----MONTPELIER WALK----
#                 venue  freq
# 0  Italian Restaurant  0.13
# 1                Café  0.12
# 2            Boutique  0.05
# 3         Coffee Shop  0.05
# 4               Hotel  0.05
#
#
# ----MULTON ROAD----
#                venue  freq
# 0                Pub  0.25
# 1     Breakfast Spot  0.25
# 2  Convenience Store  0.25
# 3       Tennis Court  0.25
# 4                ATM  0.00
#
#
# ----MUNDEN STREET----
#                venue  freq
# 0               Café  0.15
# 1              Hotel  0.09
# 2                Pub  0.09
# 3  Indian Restaurant  0.08
# 4        Pizza Place  0.08
#
#
# ----NORTH CIRCULAR ROAD----
#                     venue  freq
# 0                   Hotel   0.2
# 1  Furniture / Home Store   0.1
# 2                     Pub   0.1
# 3    Fast Food Restaurant   0.1
# 4          Hardware Store   0.1
#
#
# ----NOTTINGHAM STREET----
#                   venue  freq
# 0         Shopping Mall  0.13
# 1   American Restaurant  0.13
# 2            Restaurant  0.07
# 3  Gym / Fitness Center  0.07
# 4             Bookstore  0.07
#
#
# ----OAKLEY STREET----
#                 venue  freq
# 0  Mexican Restaurant  0.17
# 1   Convenience Store  0.17
# 2                Park  0.17
# 3         Supermarket  0.17
# 4    Basketball Court  0.17
#
#
# ----OAKWOOD COURT----
#          venue  freq
# 0         Food   0.2
# 1  Pizza Place   0.2
# 2  Video Store   0.2
# 3  Golf Course   0.2
# 4      Dog Run   0.2
#
#
# ----OBSERVATORY GARDENS----
#             venue  freq
# 0            Café  0.08
# 1             Pub  0.06
# 2  Clothing Store  0.06
# 3       Juice Bar  0.04
# 4      Restaurant  0.03
#
#
# ----OLD COURT PLACE----
#             venue  freq
# 0           Hotel  0.08
# 1       Juice Bar  0.07
# 2  Clothing Store  0.05
# 3          Garden  0.05
# 4      Restaurant  0.05
#
#
# ----ONSLOW MEWS WEST----
#                 venue  freq
# 0               Hotel  0.11
# 1        Burger Joint  0.05
# 2  Italian Restaurant  0.05
# 3              Bakery  0.05
# 4      Sandwich Place  0.04
#
#
# ----PANTON STREET----
#             venue  freq
# 0          Bakery  0.09
# 1           Plaza  0.05
# 2  Ice Cream Shop  0.05
# 3         Theater  0.05
# 4           Hotel  0.03
#
#
# ----PARK LANE----
#                 venue  freq
# 0          Print Shop  0.25
# 1                Park  0.25
# 2  Athletics & Sports  0.25
# 3         Golf Course  0.25
# 4                 ATM  0.00
#
#
# ----PARKE ROAD----
#                   venue  freq
# 0           Yoga Studio   0.2
# 1  Gym / Fitness Center   0.2
# 2                  Pool   0.2
# 3             Reservoir   0.2
# 4      Community Center   0.2
#
#
# ----PARKFIELDS----
#                   venue  freq
# 0         Historic Site   0.4
# 1       Harbor / Marina   0.2
# 2           Supermarket   0.2
# 3                 Hotel   0.2
# 4  Outdoor Supply Store   0.0
#
#
# ----PARTHENIA ROAD----
#            venue  freq
# 0  Grocery Store  0.15
# 1            Pub  0.12
# 2    Coffee Shop  0.12
# 3         Bakery  0.08
# 4           Café  0.08
#
#
# ----PAVILION ROAD----
#                         venue  freq
# 0                       Hotel  0.29
# 1                         Pub  0.14
# 2                   Nightclub  0.14
# 3                       Beach  0.14
# 4  Construction & Landscaping  0.14
#
#
# ----PEMBRIDGE MEWS----
#                 venue  freq
# 0                 Pub  0.06
# 1  Italian Restaurant  0.06
# 2          Restaurant  0.04
# 3       Grocery Store  0.03
# 4         Coffee Shop  0.03
#
#
# ----PEMBRIDGE ROAD----
#            venue  freq
# 0            Pub  0.15
# 1          Hotel  0.04
# 2    Yoga Studio  0.04
# 3           Park  0.04
# 4  Grocery Store  0.04
#
#
# ----PEMBROKE STUDIOS----
#                 venue  freq
# 0               Hotel  0.15
# 1                 Pub  0.10
# 2                Café  0.10
# 3  Italian Restaurant  0.05
# 4         Supermarket  0.05
#
#
# ----PENCOMBE MEWS----
#                 venue  freq
# 0  Italian Restaurant  0.09
# 1                 Pub  0.06
# 2         Coffee Shop  0.04
# 3              Bakery  0.04
# 4                Café  0.04
#
#
# ----PETERSHAM PLACE----
#                      venue  freq
# 0                      Pub  0.50
# 1   Furniture / Home Store  0.25
# 2  Health & Beauty Service  0.25
# 3     Outdoor Supply Store  0.00
# 4              Pastry Shop  0.00
#
#
# ----PHILLIMORE GARDENS----
#                 venue  freq
# 0                Café  0.17
# 1                 Pub  0.06
# 2      Ice Cream Shop  0.04
# 3  Italian Restaurant  0.04
# 4               Beach  0.03
#
#
# ----PHYSIC PLACE----
#                   venue  freq
# 0                   Pub  0.07
# 1                  Café  0.07
# 2        Ice Cream Shop  0.05
# 3  Gym / Fitness Center  0.05
# 4           Pizza Place  0.05
#
#
# ----PITFIELD STREET----
#                    venue  freq
# 0            Coffee Shop  0.09
# 1                    Pub  0.06
# 2                   Café  0.06
# 3           Cocktail Bar  0.05
# 4  Vietnamese Restaurant  0.05
#
#
# ----PRINCES GATE----
#                      venue  freq
# 0                Gift Shop   1.0
# 1                      ATM   0.0
# 2  New American Restaurant   0.0
# 3                Pawn Shop   0.0
# 4              Pastry Shop   0.0
#
#
# ----PRIORY ROAD----
#                venue  freq
# 0                Pub  0.29
# 1         Restaurant  0.13
# 2  French Restaurant  0.04
# 3        Pizza Place  0.04
# 4       Cocktail Bar  0.02
#
#
# ----PROTHERO GARDENS----
#            venue  freq
# 0  Grocery Store  0.19
# 1    Coffee Shop  0.12
# 2      Irish Pub  0.06
# 3    Pizza Place  0.06
# 4  Metro Station  0.06
#
#
# ----QUARRENDON STREET----
#                 venue  freq
# 0       Grocery Store  0.11
# 1         Coffee Shop  0.11
# 2                 Pub  0.09
# 3  Italian Restaurant  0.07
# 4                Park  0.07
#
#
# ----QUEENS GATE TERRACE----
#                   venue  freq
# 0  Fast Food Restaurant  0.18
# 1                  Food  0.18
# 2    Mexican Restaurant  0.09
# 3         Shopping Mall  0.09
# 4     Convenience Store  0.09
#
#
# ----RADSTOCK STREET----
#                   venue  freq
# 0                   Pub  0.23
# 1     French Restaurant  0.15
# 2         Grocery Store  0.15
# 3  Gym / Fitness Center  0.08
# 4                 Diner  0.08
#
#
# ----RANELAGH AVENUE----
#                venue  freq
# 0               Park  0.24
# 1         Restaurant  0.06
# 2  Food & Drink Shop  0.06
# 3          Bookstore  0.06
# 4              Track  0.06
#
#
# ----REDCLIFFE ROAD----
#              venue  freq
# 0           Office   0.4
# 1  Airport Service   0.2
# 2      Dry Cleaner   0.2
# 3     Home Service   0.2
# 4              ATM   0.0
#
#
# ----REEVES MEWS----
#                venue  freq
# 0              Hotel  0.15
# 1               Café  0.06
# 2  French Restaurant  0.06
# 3       Cocktail Bar  0.05
# 4           Tea Room  0.05
#
#
# ----RHEIDOL MEWS----
#           venue  freq
# 0           Pub  0.13
# 1   Coffee Shop  0.05
# 2          Park  0.05
# 3          Café  0.04
# 4  Burger Joint  0.04
#
#
# ----RINGWOOD AVENUE----
#                    venue  freq
# 0            Pizza Place  0.25
# 1   Gym / Fitness Center  0.25
# 2      Convenience Store  0.25
# 3       Business Service  0.25
# 4  Outdoors & Recreation  0.00
#
#
# ----RODERICK ROAD----
#                   venue  freq
# 0                  Café  0.17
# 1  Gym / Fitness Center  0.11
# 2     Convenience Store  0.06
# 3         Train Station  0.06
# 4         Track Stadium  0.06
#
#
# ----ROPEMAKERS FIELDS----
#                   venue  freq
# 0    Italian Restaurant  0.08
# 1     Indian Restaurant  0.08
# 2  Gym / Fitness Center  0.08
# 3                   Pub  0.08
# 4                 Hotel  0.04
#
#
# ----ROYAL CRESCENT----
#                 venue  freq
# 0                Café  0.08
# 1               Hotel  0.08
# 2                 Pub  0.08
# 3  Italian Restaurant  0.08
# 4          Restaurant  0.08
#
#
# ----RUSSELL GARDENS MEWS----
#                venue  freq
# 0              Hotel  0.19
# 1                Pub  0.12
# 2  Indian Restaurant  0.08
# 3          Gastropub  0.08
# 4  Convention Center  0.08
#
#
# ----SETTLES STREET----
#                venue  freq
# 0              Hotel  0.12
# 1        Coffee Shop  0.10
# 2               Café  0.07
# 3  Indian Restaurant  0.07
# 4                Pub  0.05
#
#
# ----SHELDON AVENUE----
#                    venue  freq
# 0                 Bakery  0.33
# 1                   Park  0.33
# 2      Food & Drink Shop  0.33
# 3  Outdoors & Recreation  0.00
# 4       Pedestrian Plaza  0.00
#
#
# ----SOUTH END ROW----
#                venue  freq
# 0              Hotel  0.08
# 1          Juice Bar  0.08
# 2  Indian Restaurant  0.06
# 3         Restaurant  0.06
# 4     Clothing Store  0.06
#
#
# ----SOUTHWOOD LAWN ROAD----
#                 venue  freq
# 0                 Pub  0.30
# 1  Italian Restaurant  0.06
# 2         Coffee Shop  0.06
# 3   Indian Restaurant  0.06
# 4                Café  0.06
#
#
# ----SOVEREIGN PARK----
#                     venue  freq
# 0  Furniture / Home Store  0.21
# 1    Fast Food Restaurant  0.14
# 2       Electronics Store  0.14
# 3             Supermarket  0.14
# 4                   Hotel  0.07
#
#
# ----ST OSWALDS PLACE----
#          venue  freq
# 0          Pub  0.12
# 1        Hotel  0.10
# 2         Café  0.07
# 3      Gay Bar  0.07
# 4  Art Gallery  0.05
#
#
# ----ST PETERS SQUARE----
#                 venue  freq
# 0  Italian Restaurant  0.23
# 1      Ice Cream Shop  0.10
# 2                Café  0.09
# 3               Hotel  0.09
# 4      Sandwich Place  0.04
#
#
# ----STAFFORD TERRACE----
#           venue  freq
# 0          Café  0.10
# 1        Bakery  0.06
# 2    Restaurant  0.04
# 3  Burger Joint  0.04
# 4        Garden  0.04
#
#
# ----SUTHERLAND PLACE----
#                 venue  freq
# 0                 Pub  0.08
# 1                Café  0.06
# 2                 Bar  0.05
# 3  Italian Restaurant  0.05
# 4  Persian Restaurant  0.05
#
#
# ----SYDNEY STREET----
#                    venue  freq
# 0                   Café  0.22
# 1               Platform  0.10
# 2                Brewery  0.08
# 3        Thai Restaurant  0.05
# 4  Vietnamese Restaurant  0.05
#
#
# ----THAMES BANK----
#                   venue  freq
# 0          Burger Joint  0.25
# 1  Gym / Fitness Center  0.25
# 2         Grocery Store  0.25
# 3           Pizza Place  0.25
# 4                   ATM  0.00
#
#
# ----THE HEXAGON----
#               venue  freq
# 0    Clothing Store  0.11
# 1               Pub  0.08
# 2       Coffee Shop  0.08
# 3               Bar  0.05
# 4  Asian Restaurant  0.05
#
#
# ----TREDEGAR SQUARE----
#                   venue  freq
# 0                   Pub  0.19
# 1           Pizza Place  0.12
# 2  Fast Food Restaurant  0.08
# 3           Coffee Shop  0.08
# 4   Fried Chicken Joint  0.04
#
#
# ----TRINITY STREET----
#                   venue  freq
# 0  Fast Food Restaurant  0.15
# 1           Supermarket  0.08
# 2              Pharmacy  0.08
# 3           Coffee Shop  0.08
# 4         Train Station  0.08
#
#
# ----UPPER HAMPSTEAD WALK----
#                 venue  freq
# 0                 Pub  0.11
# 1                Café  0.11
# 2              Bakery  0.07
# 3  Italian Restaurant  0.05
# 4         Coffee Shop  0.04
#
#
# ----WALPOLE GARDENS----
#          venue  freq
# 0          Pub  0.13
# 1         Café  0.09
# 2         Park  0.09
# 3  Coffee Shop  0.09
# 4     Platform  0.07
#
#
# ----WALPOLE STREET----
#                         venue  freq
# 0                        Café  0.50
# 1               Grocery Store  0.25
# 2  Tourist Information Center  0.25
# 3                         ATM  0.00
# 4        Outdoor Supply Store  0.00
#
#
# ----WARWICK SQUARE----
#                     venue  freq
# 0           Shopping Mall  0.09
# 1             Pizza Place  0.09
# 2  Furniture / Home Store  0.05
# 3          Sandwich Place  0.05
# 4                    Bank  0.05
#
#
# ----WELBECK WAY----
#                   venue  freq
# 0           Yoga Studio  0.25
# 1  Gym / Fitness Center  0.25
# 2       Warehouse Store  0.25
# 3            Playground  0.25
# 4                   ATM  0.00
#
#
# ----WELLESLEY TERRACE----
#                        venue  freq
# 0              Grocery Store  0.22
# 1               Burger Joint  0.11
# 2         Athletics & Sports  0.11
# 3       Fast Food Restaurant  0.11
# 4  Middle Eastern Restaurant  0.11
#
#
# ----WELLINGTON STREET----
#          venue  freq
# 0  Coffee Shop  0.20
# 1   Restaurant  0.06
# 2        Hotel  0.05
# 3   Food Truck  0.04
# 4  Salad Place  0.04
#
#
# ----WESTMORELAND PLACE----
#                          venue  freq
# 0  Eastern European Restaurant  0.07
# 1                  Art Gallery  0.07
# 2                     Pharmacy  0.07
# 3                  Flower Shop  0.07
# 4                       Bakery  0.07
#
#
# ----WHITFIELD STREET----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1   Indian Restaurant  0.08
# 2                 Pub  0.05
# 3  Italian Restaurant  0.04
# 4          Restaurant  0.03
#
#
# ----WILFRED STREET----
#                    venue  freq
# 0      Convenience Store   0.5
# 1         History Museum   0.5
# 2                    ATM   0.0
# 3  Outdoors & Recreation   0.0
# 4       Pedestrian Plaza   0.0
#
#
# ----WILLOW BRIDGE ROAD----
#               venue  freq
# 0               Pub  0.22
# 1       Coffee Shop  0.13
# 2              Café  0.09
# 3          Bus Stop  0.09
# 4  Asian Restaurant  0.04
#
#
# ----WILSON STREET----
#                 venue  freq
# 0  Mexican Restaurant  0.18
# 1         Coffee Shop  0.12
# 2                 ATM  0.06
# 3         Video Store  0.06
# 4      Farmers Market  0.06

# %%
# Define a function to return the most common venues/facilities nearby real estate investments#

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Street']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# %%
# create a new dataframe
venues_sorted = pd.DataFrame(columns=columns)
venues_sorted['Street'] = london_grouped['Street']

for ind in np.arange(london_grouped.shape[0]):
    venues_sorted.iloc[ind, 1:] = return_most_common_venues(london_grouped.iloc[ind, :], num_top_venues)

# %%
venues_sorted.head()
# Out:
#             Street  ... 10th Most Common Venue
# 0    ALBION SQUARE  ...            Supermarket
# 1  ANSDELL TERRACE  ...                   Café
# 2  APPLEGARTH ROAD  ...                   Farm
# 3  BARONSMEAD ROAD  ...            Coffee Shop
# 4   BEAUCLERC ROAD  ...   Fast Food Restaurant
#
# [5 rows x 11 columns]

# %%
venues_sorted.shape
# Out:
# (144, 11)

# %%
london_grouped.shape
# Out:
# (144, 349)

# %%
london_grouped=df

# %% [markdown]
# After our inspection of venues/facilities/amenities nearby the most profitable real estate investments in London, we could begin by clustering properties by venues/facilities/amenities nearby.

# %%
#Distribute in 5 Clusters

# set number of clusters
kclusters = 5

london_grouped_clustering = london_grouped.drop('Street', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(london_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:50]
# Out:
# array([1, 4, 2, 4, 0, 1, 0, 2, 2, 1, 4, 4, 1, 0, 0, 1, 4, 2, 1, 3, 3, 4,
#        1, 1, 2, 4, 3, 1, 2, 4, 0, 4, 0, 0, 3, 4, 4, 0, 2, 1, 0, 3, 2, 3,
#        2, 2, 3, 2, 2, 4], dtype=int32)

# %%
#Dataframe to include Clusters

london_grouped_clustering=df
london_grouped_clustering.head()
# Out:
#               Street  Avg_Price   Latitude   Longitude
# 196    ALBION SQUARE  2450000.0 -41.273758  173.289393
# 390      ANHALT ROAD  2435000.0  29.805547  -98.475534
# 405  ANSDELL TERRACE  2250000.0  51.500005   -0.189154
# 422  APPLEGARTH ROAD  2400000.0  40.271236  -74.471110
# 857  BARONSMEAD ROAD  2375000.0  51.477315   -0.239457

# %%
london_grouped_clustering.shape
# Out:
# (159, 4)

# %%
df.shape
# Out:
# (159, 4)

# %%
london_grouped_clustering.dtypes
# Out:
# Street        object
# Avg_Price    float64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
df.dtypes
# Out:
# Street        object
# Avg_Price    float64
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
# add clustering labels
london_grouped_clustering['Cluster Labels'] = kmeans.labels_

# merge london_grouped with london_data to add latitude/longitude for each neighborhood
london_grouped_clustering = london_grouped_clustering.join(venues_sorted.set_index('Street'), on='Street')

london_grouped_clustering.head(30) # check the last columns!
# Out:
#                    Street  ...  10th Most Common Venue
# 196         ALBION SQUARE  ...             Supermarket
# 390           ANHALT ROAD  ...                     NaN
# 405       ANSDELL TERRACE  ...                    Café
# 422       APPLEGARTH ROAD  ...                    Farm
# 857       BARONSMEAD ROAD  ...             Coffee Shop
# 983        BEAUCLERC ROAD  ...    Fast Food Restaurant
# 1105      BELVEDERE DRIVE  ...     Filipino Restaurant
# 1218    BICKENHALL STREET  ...                  Museum
# 1256    BIRCHLANDS AVENUE  ...             Flower Shop
# 1556       BRAMPTON GROVE  ...     Filipino Restaurant
# 1635    BRIARDALE GARDENS  ...                    Farm
# 1800             BROOKWAY  ...                     NaN
# 1983            BURY WALK  ...                    Park
# 2071      CALLCOTT STREET  ...             Coffee Shop
# 2132    CAMPDEN HILL ROAD  ...       Fish & Chips Shop
# 2139         CAMPION ROAD  ...          Farmers Market
# 2161        CANNING PLACE  ...             Coffee Shop
# 2228        CARLISLE ROAD  ...             Film Studio
# 2233      CARLTON GARDENS  ...       Convenience Store
# 2245        CARLYLE COURT  ...             Film Studio
# 2408       CHALCOT SQUARE  ...              Beer Store
# 2486         CHARLES LANE  ...                 Factory
# 2564     CHELSEA CRESCENT  ...           Grocery Store
# 2608  CHESTER CLOSE NORTH  ...                Beer Bar
# 2640         CHEYNE COURT  ...               Gift Shop
# 2643           CHEYNE ROW  ...            Burger Joint
# 2688        CHISWICK MALL  ...      Falafel Restaurant
# 2763            CITY ROAD  ...                     Spa
# 2810     CLARENDON STREET  ...                    Farm
# 2902     CLONCURRY STREET  ...                  Garden
#
# [30 rows x 15 columns]

# %%
# Create Map

map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(london_grouped_clustering['Latitude'], london_grouped_clustering['Longitude'], london_grouped_clustering['Street'], london_grouped_clustering['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_228e94da81ee4024912d63ddba9d1326%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_228e94da81ee4024912d63ddba9d1326%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_228e94da81ee4024912d63ddba9d1326%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_228e94da81ee4024912d63ddba9d1326%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B51.5073219%2C%20-0.1276474%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_a657a9e8762a4434abcaab637d7e05cc%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%2 ...

# %%
london_grouped_clustering.loc[london_grouped_clustering['Cluster Labels'] == 0, london_grouped_clustering.columns[[1] + list(range(5, london_grouped_clustering.shape[1]))]].head()
# Out:
#       Avg_Price  ... 10th Most Common Venue
# 857   2375000.0  ...            Coffee Shop
# 1105  2340000.0  ...    Filipino Restaurant
# 2071  2375000.0  ...            Coffee Shop
# 2132  2379652.7  ...      Fish & Chips Shop
# 2946  2367500.0  ...   Gym / Fitness Center
#
# [5 rows x 11 columns]

# %%
london_grouped_clustering.loc[london_grouped_clustering['Cluster Labels'] == 1, london_grouped_clustering.columns[[1] + list(range(5, london_grouped_clustering.shape[1]))]].head()
# Out:
#       Avg_Price  ... 10th Most Common Venue
# 196   2450000.0  ...            Supermarket
# 983   2480000.0  ...   Fast Food Restaurant
# 1556  2456875.0  ...    Filipino Restaurant
# 1983  2492500.0  ...                   Park
# 2139  2461000.0  ...         Farmers Market
#
# [5 rows x 11 columns]

# %%
london_grouped_clustering.loc[london_grouped_clustering['Cluster Labels'] == 2, london_grouped_clustering.columns[[1] + list(range(5, london_grouped_clustering.shape[1]))]].head()
# Out:
#       Avg_Price  ... 10th Most Common Venue
# 405   2250000.0  ...                   Café
# 1218  2208500.0  ...                 Museum
# 1256  2217000.0  ...            Flower Shop
# 2228  2200000.0  ...            Film Studio
# 2640  2250000.0  ...              Gift Shop
#
# [5 rows x 11 columns]

# %%
london_grouped_clustering.loc[london_grouped_clustering['Cluster Labels'] == 3, london_grouped_clustering.columns[[1] + list(range(5, london_grouped_clustering.shape[1]))]].head()
# Out:
#          Avg_Price  ... 10th Most Common Venue
# 2245  2.300000e+06  ...            Film Studio
# 2408  2.286679e+06  ...             Beer Store
# 2688  2.287500e+06  ...     Falafel Restaurant
# 3379  2.298000e+06  ...    Filipino Restaurant
# 4287  2.265000e+06  ...      French Restaurant
#
# [5 rows x 11 columns]

# %%
london_grouped_clustering.loc[london_grouped_clustering['Cluster Labels'] == 4, london_grouped_clustering.columns[[1] + list(range(5, london_grouped_clustering.shape[1]))]].head()
# Out:
#       Avg_Price  ... 10th Most Common Venue
# 390   2435000.0  ...                    NaN
# 422   2400000.0  ...                   Farm
# 1635  2397132.0  ...                   Farm
# 1800  2400000.0  ...                    NaN
# 2161  2425000.0  ...            Coffee Shop
#
# [5 rows x 11 columns]

# %% [markdown]
# **Results and Discussion section**
#
# First of all, even though the London Housing Market may be in a rut, it is still an "ever-green" for business affairs.
#
# We may discuss our results under two main perspectives.
#
# First, we may examine them according to neighborhoods/London areas. It is interesting to note that, although West London (Notting Hill, Kensington, Chelsea, Marylebone) and North-West London (Hampsted) might be considered highly profitable venues to purchase a real estate according to amenities and essential facilities surrounding such venues i.e. elementary schools, high schools, hospitals & grocery stores, South-West London (Wandsworth, Balham) and North-West London (Isliington) are arising as next future elite venues with a wide range of amenities and facilities. Accordingly, one might target under-priced real estates in these areas of London in order to make a business affair.
#
# Second, we may analyze our results according to the five clusters we have produced. Even though, all clusters could praise an optimal range of facilities and amenities, we have found two main patterns. The first pattern we are referring to, i.e. Clusters 0, 2 and 4, may target home buyers prone to live in 'green' areas with parks, waterfronts. Instead, the second pattern we are referring to, i.e. Clusters 1 and 3, may target individuals who love pubs, theatres and soccer.
#
# **Conclusion**
#
# To sum up, according to Bloomberg News, the London Housing Market is in a rut. It is now facing a number of different headwinds, including the prospect of higher taxes and a warning from the Bank of England that U.K. home values could fall as much as 30 percent in the event of a disorderly exit from the European Union. In this scenario, it is urgent to adopt machine learning tools in order to assist homebuyers clientele in London to make wise and effective decisions. As a result, the business problem we were posing was: how could we provide support to homebuyers clientele in to purchase a suitable real estate in London in this uncertain economic and financial scenario?
#
# To solve this business problem, we clustered London neighborhoods in order to recommend venues and the current average price of real estate where homebuyers can make a real estate investment. We recommended profitable venues according to amenities and essential facilities surrounding such venues i.e. elementary schools, high schools, hospitals & grocery stores.
#
# First, we gathered data on London properties and the relative price paid data were extracted from the HM Land Registry (http://landregistry.data.gov.uk/). Moreover, to explore and target recommended locations across different venues according to the presence of amenities and essential facilities, we accessed data through FourSquare API interface and arranged them as a data frame for visualization. By merging data on London properties and the relative price paid data from the HM Land Registry and data on amenities and essential facilities surrounding such properties from FourSquare API interface, we were able to recommend profitable real estate investments.
#
# Second, The Methodology section comprised four stages: 1. Collect Inspection Data; 2. Explore and Understand Data; 3. Data preparation and preprocessing; 4. Modeling. In particular, in the modeling section, we used the k-means clustering technique as it is fast and efficient in terms of computational cost, is highly flexible to account for mutations in real estate market in London and is accurate.
#
# Finally, we drew the conclusion that even though the London Housing Market may be in a rut, it is still an "ever-green" for business affairs. We discussed our results under two main perspectives. First, we examined them according to neighborhoods/London areas. although West London (Notting Hill, Kensington, Chelsea, Marylebone) and North-West London (Hampsted) might be considered highly profitable venues to purchase a real estate according to amenities and essential facilities surrounding such venues i.e. elementary schools, high schools, hospitals & grocery stores, South-West London (Wandsworth, Balham) and North-West London (Isliington) are arising as next future elite venues with a wide range of amenities and facilities. Accordingly, one might target under-priced real estates in these areas of London in order to make a business affair. Second, we analyzed our results according to the five clusters we produced. While Clusters 0, 2 and 4 may target home buyers prone to live in 'green' areas with parks, waterfronts, Clusters 1 and 3 may target individuals who love pubs, theatres and soccer.
